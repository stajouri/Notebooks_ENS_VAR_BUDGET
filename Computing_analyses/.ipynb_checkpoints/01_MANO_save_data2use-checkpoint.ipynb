# %% [raw]
# aim: do the ensemble analysis on manometric sea level. I first retrieve a GMmanoSL, then the time mean

# %%
import os,sys
import numpy as np
import xarray as xr
import zarr
# from dask.distributed import Client
import multiprocessing.popen_spawn_posix
from distributed import Client

c = Client()
c
# Out:
# /gpfslocalsup/pub/anaconda-py3/2020.11/envs/climate_science/lib/python3.9/site-packages/distributed/node.py:151: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 41571 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:44555' processes=5 threads=10, memory=322.12 GB>

# %%
prefix = "eORCA025.L75-IMHOTEP"
chunk_size = {"x":133,"y":320}

# ---------------------------------- weight for the GMSL calculation -----------------------------------------------
diri="/gpfswork/rech/cli/rcli002/eORCA025.L75/eORCA025.L75-I/"
mesh_hgr = xr.open_dataset(diri+'mesh_hgr.nc',chunks=chunk_size).squeeze()
tmask = mesh_hgr.tmask

e1t = mesh_hgr.e1t.fillna(0)
e2t = mesh_hgr.e2t.fillna(0)

# nav_lon =  mesh_hgr.nav_lon
# nav_lat =  mesh_hgr.nav_lat

# constructing the weight
bt = (e1t * e2t).load()# area of each cell
# getting the weights to be applied to every grid cell
# masking the land cells
oceanArea = (bt*tmask[0])  #tmask : 1 on ocean, 0 on land
totalOceanArea = oceanArea.sum()
Weight = (oceanArea/totalOceanArea).compute().drop_vars('nav_lev').drop_vars('time_counter')

# %%
# %%time

for nexp in ["ES","EAI","EGAI"]:

    diro = "/gpfsscratch/rech/cli/uor98hu/ETUDE3/ENS_VAR_BUDGET/"+nexp+"/MANO/"
    ii=1
    totb=[]
    
    # load sea ie mask to apply
    SIMSK_E = xr.open_zarr("/gpfsscratch/rech/cli/uor98hu/ETUDE3/ENS_VAR_BUDGET/"+nexp+"/"+nexp+"_SIMASK15_E1980_2018.zarr").SIMASK15_E #  Sea ice mask
    sum_simsk = SIMSK_E.sum(('ens','time_counter')).compute()
    si_mask = (sum_simsk.where(sum_simsk==390,0)/390)
    
    for Emb in ['001','002','003','004','005','006','007','008','009','010']:
        diridatref="/gpfsstore/rech/cli/rcli002/eORCA025.L75/"+prefix+"."+nexp+"."+Emb+"-S/1y/"
        data = xr.open_mfdataset(diridatref+'????/*_gridTsurf.nc', chunks = chunk_size, parallel=True).botpres.squeeze()
    
        totb.append(data.assign_coords({'ens':ii}))
        ii+=1
        
    OBP_E= xr.concat(totb, 'ens').sel(time_counter=slice("1980","2018")) # full time period
    
    # compute the manometric sea level
    MANO_E = ( OBP_E * 10000 * si_mask ) / ( 1035 * 9.81 )
    
    # retrieving the GMmanoSL
    mean_E_GMmanoSL = ((MANO_E * Weight).sum(('x','y'))).mean('ens')
    MANO_E_corr = MANO_E - mean_E_GMmanoSL
    
    # retirving the ensemble mean time mean at each point 
    MANO_E_corr_tmean = MANO_E_corr.mean('time_counter').mean('ens')
    MANO_E_corr_shifted = ( MANO_E_corr - MANO_E_corr_tmean ).compute()
    
    MANO_E_corr_shifted.to_dataset(name="MANO_E").to_zarr(diro+"MANO_E_2use_1980_2018.zarr", mode='w')
# Out:
# distributed.utils_perf - WARNING - full garbage collections took 10% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 12% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# distributed.utils_perf - WARNING - full garbage collections took 11% CPU time recently (threshold: 10%)
# ...

# %%
# --------------------------------------------------- calculating the GMSL and saving it
# GMSL_MANO_E = (MANO_E * Weight).sum(('x','y'))
# namo = "GMSL_MANO" + nexp
# GMSL_MANO_E.to_dataset(name="GMSL").to_zarr(diro+namo+"1980_2018.zarr", mode='w')
# namo = "GMSL_MANO" + nexp
# GMSL_MANO_E_open = xr.open_dataset(diro+namo+"1980_2018.zarr", engine="zarr").GMSL
# mean_E_GMSL = GMSL_MANO_E_open.mean('ens')

# for ii in np.arange(1,10):
#     (GMSL_MANO_E_open.isel(ens=ii)) .plot()
# mean_E_GMSL.plot(color='k')

# %%
# -------------------------------------------------- compute the time mean and save it
# MANO_E_corr_tmean = MANO_E_corr.mean('time_counter').compute()
# MANO_E_corr_tmean.to_dataset(name="MANO_E_corr_tmean").to_zarr(diro+"MANO_E_corr_tmean_"+nexp+"1980_2018.zarr", mode='w')
# MANO_E_corr_tmean = xr.open_dataset(diro+"MANO_E_corr_tmean_"+nexp+"1980_2018.zarr", engine="zarr").MANO_E_corr_tmean
# MANO_E_corr_tmean_ensmean_2apply = MANO_E_corr_tmean.mean('ens')
# MANO_E_corr_shifted.to_dataset(name="MANO_E").to_zarr(diro+"MANO_E_2use_"+nexp+"_1980_2018.zarr", mode='w')

# %%
import matplotlib.pyplot as plt
plt.figure( figsize = (20,13) )
MANO_E_corr_shifted[0,0].plot()
